# %% [markdown]
# # Drawing patches with polygons
#
# - How to define polygons and draw "patches" on plots.

# %%
# import required packages at the top of the script!
import sympy as sym
import numpy as np
from IPython.display import display, Math
import matplotlib.pyplot as plt
from matplotlib.patches import Polygon

# %%
y = np.array([ [1,1],[2,3],[3,1] ])
p = Polygon(y,facecolor='m',alpha=.3)

# extend with two polygons
y1 = np.array([ [2,2],[2.5,4],[3.5,1] ])
p1 = Polygon(y1,alpha=.2,edgecolor='k')

fig, ax = plt.subplots()

ax.add_patch(p1)
ax.add_patch(p)

ax.set_ylim([0,4])
ax.set_xlim([0,4])
plt.show()

# %% [markdown]
# ### Exercise

# %%
# Create fx
x = np.linspace(-2,2,101)
Fx = -x**2
y = np.vstack((x,f)).T

fig, ax = plt.subplots()

p1 = Polygon(np.array([ [-0.5, -4], [0.5, -4],  [0.5, -2.5], [-0.5, -2.5], ]),facecolor='k')
p2 = Polygon( y ,facecolor='g', alpha=.3, edgecolor='k')

ax.add_patch(p1)
ax.add_patch(p2)

ax.set_ylim([-4.5, 0])
ax.set_xlim([-2.5, 2.5])

plt.plot(x,f,'k')
plt.plot(x[[0,-1]],[-4,-4],'k')
plt.show()
