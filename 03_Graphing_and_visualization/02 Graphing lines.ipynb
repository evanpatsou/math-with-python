# %% [markdown]
# # Graphing lines
#
# - How to describe a line using start/stop form.
# - Plotting lines in Python.
# - How to plot with colors

# %%
import sympy as sym
import numpy as np
from IPython.display import display, Math
import matplotlib.pyplot as plt

# %%
# drawing lines

p1 = [-3,-1]
p2 = [4,4]

# nice try, but wrong code :(
plt.plot(p1,p2)
plt.plot([p1[0],p2[0]],[p1[1],p2[1]],color=[.7,.3,.8],linewidth=5)

plt.axis('square')
plt.axis([-6,6,-6,6])
plt.show()

# %%
x = 3
y = 5

# basic plotting a red dot
plt.plot(x,y,'ro')
plt.plot([0,x],[0,y],'r')

# set axis limits
plt.axis('square') # order matters
plt.axis([-6,6,-6,6])
plt.grid()

# now add lines
plt.plot([-6,6],[0,0],'k')
plt.plot([0,0],[-6,6],'k')

plt.show()

# %% [markdown]
# ### Exercises

# %%
# Initialize the variables
xSpace = [i for i in range(-20, 21)]

# initialize the function
x = sym.symbols('x')
y = sym.sqrt(abs(x))

for num in xSpace: 
    plt.plot([0, num], [0, y.subs({x:num}).evalf()] )
    
plt.xlabel('x')
plt.ylabel('y')
plt.show()

# %%
plt.plot([0, 2], [0,0])
plt.plot([0, 2], [2,2])
plt.plot([0, 0], [0,2])
plt.plot([2, 2], [0,2])

# set axis limits
plt.axis('square')
plt.axis([-3,5,-3,5])
plt.show()
